# %%
# Variable assignments
a = 1
b = 0.5
char_var = 'a'  # Renamed 'char' to 'char_var' to avoid conflict with built-in 'char' (if it existed)

print("int operation")
sum_result = a + b  # Renamed 'sum' to 'sum_result' to avoid conflict with built-in 'sum' function
print("sum a+b =", sum_result)

print("float operation")
# Assuming 'c' is intended to be another numerical value for division
c = 2.0
d = b / c
print("float =", d)

print("string operation")
string_var = 'atharv'  # Corrected string assignment and renamed 'str' to 'string_var'
print("str =", string_var)

print("type", type(a))
print("type", type(b))
print("type", type(char_var))
# Out:
# int operation
# sum a+b = 1.5
# float operation
# float = 0.25
# string operation
# str = atharv
# type <class 'int'>
# type <class 'float'>
# type <class 'str'>
